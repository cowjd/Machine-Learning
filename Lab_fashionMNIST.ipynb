# %% [markdown]
# # **colab 서버에서 지원하는 환경 확인하기**

# %%
# colab의 서버에서 지원하고 있는 os는 무엇인지 확인
import platform
platform.platform()
# Out:
# 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------
# absl-py                       0.12.0
# alabaster                     0.7.12
# albumentations                0.1.12
# altair                        4.1.0
# appdirs                       1.4.4
# argcomplete                   1.12.3
# argon2-cffi                   21.1.0
# arviz                         0.11.4
# astor                         0.8.1
# astropy                       4.3.1
# astunparse                    1.6.3
# atari-py                      0.2.9
# atomicwrites                  1.4.0
# attrs                         21.2.0
# audioread                     2.1.9
# autograd                      1.3
# Babel                         2.9.1
# backcall                      0.2.0
# beautifulsoup4                4.6.3
# bleach                        4.1.0
# blis                          0.4.1
# bokeh                         2.3.3
# Bottleneck                    1.3.2
# ...

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 63
# model name	: Intel(R) Xeon(R) CPU @ 2.30GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2299.998
# cache size	: 46080 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 avx2 smep bmi2 erms invpcid xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4599.99
# clflush size	: 64
# cache_alignment	: 64
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13302924 kB
# MemFree:        10645896 kB
# MemAvailable:   12465380 kB
# Buffers:          125284 kB
# Cached:          1837808 kB
# SwapCached:            0 kB
# Active:           960304 kB
# Inactive:        1438872 kB
# Active(anon):     395616 kB
# Inactive(anon):      424 kB
# Active(file):     564688 kB
# Inactive(file):  1438448 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               764 kB
# Writeback:             0 kB
# AnonPages:        436084 kB
# Mapped:           239296 kB
# Shmem:              1164 kB
# KReclaimable:     115648 kB
# Slab:             163404 kB
# SReclaimable:     115648 kB
# SUnreclaim:        47756 kB
# KernelStack:        4880 kB
# PageTables:         5912 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6651460 kB
# Committed_AS:    3037460 kB
# VmallocTotal:   34359738367 kB
# ...

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !nvidia-smi

# %% [markdown]
# # **필요 라이브러리 설치하기**

# %%
# !pip uninstall -y tensorflow
# Out:
# Found existing installation: tensorflow 2.7.0
# Uninstalling tensorflow-2.7.0:
#   Successfully uninstalled tensorflow-2.7.0

# %%
# !pip install tensorflow-gpu==2.0.0
# Out:
# ...
#      |████████████████████████████████| 380.8 MB 39 kB/s
# ...
#      |████████████████████████████████| 50 kB 6.3 MB/s
# ...
#      |████████████████████████████████| 449 kB 41.7 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 40.1 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=5e0c4b45b1c3b630a9e25c9a695499bff83f18da0b6c0c5be5f5525aa37b2b89
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.7.0
#     Uninstalling tensorflow-estimator-2.7.0:
#       Successfully uninstalled tensorflow-estimator-2.7.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.7.0
#     Uninstalling tensorboard-2.7.0:
#       Successfully uninstalled tensorboard-2.7.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
# ...

# %%
pip uninstall -y h5py
# Out:
# Found existing installation: h5py 3.1.0
# Uninstalling h5py-3.1.0:
#   Successfully uninstalled h5py-3.1.0

# %%
pip install h5py==2.10.0
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 5.4 MB/s
# ...

# %% [markdown]
# # **설치 버전 확인 및 라이브러리 임포트하기**

# %%
import os
import time
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras import regularizers, callbacks
tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# # [**패션 MNIST 데이터셋**](https://github.com/zalandoresearch/fashion-mnist)을 로드하여 준비
#
# ![FashiMNIST sample](https://www.tensorflow.org/images/fashion-mnist-sprite.png)

# %% [markdown]
# - 이미지는 28x28 크기의 넘파이 배열
# - 픽셀 값은 0과 255 사이입
# - *레이블*(label)은 0에서 9까지의 정수 배열(이미지에 있는 옷의 *클래스*(class))
#
# <table>
#   <tr>
#     <th>레이블</th>
#     <th>클래스</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# # **데이터 탐색하기**

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %% [markdown]
# # **데이터셋 시각화해보기**

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.colorbar()
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# # **데이터 정규화(전처리)**

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# # **모델 설계하기**
#   - 층을 차례대로 쌓아 `tf.keras.Sequential` 모델을 만듬.
#
# ![img](https://www.researchgate.net/profile/Haohan-Wang-4/publication/282997080/figure/fig4/AS:305939199610886@1449952997594/A-typical-two-layer-neural-network-Input-layer-does-not-count-as-the-number-of-layers-of.png)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
  tf.keras.layers.BatchNormalization(momentum=0.9),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# flatten_28 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dense_61 (Dense)             (None, 128)               100480
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_62 (Dense)             (None, 10)                1290
# ...
# Total params: 102,282
# Trainable params: 102,026
# Non-trainable params: 256
# _________________________________________________________________

# %% [markdown]
# # **콜백을 사용하여 학습과정 제어하기**

# %%
from tensorflow.keras import callbacks

def lr_schedule(epoch):
    """Learning Rate Schedule
    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = lr_begin
    if epoch > EPOCH_2:
        lr *= 1e-2
    elif epoch > EPOCH_1:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# callbacks: LearningRateScheduler
lr_scheduler = callbacks.LearningRateScheduler(lr_schedule)  

# callbacks: 
model_checkpoint = callbacks.ModelCheckpoint(
    filepath = 'fashionMNIST_model.h5',
    monitor = 'val_loss',
    save_best_only = True)

callbacks = [lr_scheduler, model_checkpoint]

# %% [markdown]
# # **모델 컴파일 수행하기**
#   - 훈련에 사용할 옵티마이저(optimizer)와 손실 함수를 선택

# %%
lr_begin = 1e-3
EPOCH_1 = round(Epochs/2)
EPOCH_2 = round(Epochs*3/4)

opt = Adam(lr=lr_begin)
model.compile(optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # **모델 훈련하기**

# %%
Epochs = 50
Starttime = time.time()
history = model.fit(train_images, 
                    train_labels, 
                    batch_size=128,
                    epochs=Epochs,
                    callbacks = callbacks,
                    validation_split=0.3)
Endtime = time.time()
print("[Info.] Training time is = {0:.2f} min.".format((Endtime-Starttime)/60))
# Out:
# Train on 42000 samples, validate on 18000 samples
# Learning rate:  0.001
# Epoch 1/50
# 42000/42000 [==============================] - 3s 79us/sample - loss: 0.5546 - accuracy: 0.8137 - val_loss: 0.4801 - val_accuracy: 0.8388
# Learning rate:  0.001
# Epoch 2/50
# 42000/42000 [==============================] - 2s 58us/sample - loss: 0.4270 - accuracy: 0.8556 - val_loss: 0.4479 - val_accuracy: 0.8438
# Learning rate:  0.001
# Epoch 3/50
# 42000/42000 [==============================] - 2s 58us/sample - loss: 0.3910 - accuracy: 0.8676 - val_loss: 0.3928 - val_accuracy: 0.8681
# Learning rate:  0.001
# Epoch 4/50
# 42000/42000 [==============================] - 2s 57us/sample - loss: 0.3736 - accuracy: 0.8712 - val_loss: 0.4038 - val_accuracy: 0.8626
# Learning rate:  0.001
# Epoch 5/50
# 42000/42000 [==============================] - 2s 56us/sample - loss: 0.3565 - accuracy: 0.8790 - val_loss: 0.3763 - val_accuracy: 0.8724
# Learning rate:  0.001
# Epoch 6/50
# ...

# %% [markdown]
# # **학습결과 확인하기**

# %%
def smooth_curve(points, factor=0.8):
  smoothed_points = []
  for point in points:
    if smoothed_points:
      previous = smoothed_points[-1]
      smoothed_points.append(previous * factor + point * (1 - factor))
    else:
      smoothed_points.append(point)
  return smoothed_points

plt.figure(figsize=(15,5))
plt.subplots_adjust(wspace=0.5)


loss = smooth_curve(history.history['loss'])
val_loss = smooth_curve(history.history['val_loss'])
accuracy = smooth_curve(history.history['accuracy'])
val_accuracy = smooth_curve(history.history['val_accuracy'])

# 학습 곡선 표시
plt.subplot(1,2,1)
plt.plot(loss, 'black',label='training')
plt.plot(val_loss, 'cornflowerblue',label='test')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.title('Training and validation loss')
plt.legend()
plt.xlim([0, Epochs])
plt.xticks(np.arange(0, Epochs, step=5))
plt.grid(True)

# 정확도 곡선 표시
plt.subplot(1,2,2)
plt.plot(accuracy, 'black',label='training')
plt.plot(val_accuracy, 'cornflowerblue',label='test')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.xlim([0, Epochs])
plt.xticks(np.arange(0, Epochs, step=5))
plt.grid(True)
plt.show()

# %% [markdown]
# # **학습데이터 전체 사용하여 학습하기**

# %%
Epochs = 50
lr_begin = 1e-3
EPOCH_1 = round(Epochs/2)
EPOCH_2 = round(Epochs*3/4)

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.0001)),
  tf.keras.layers.BatchNormalization(momentum=0.9),
  tf.keras.layers.Dropout(0.1),
  tf.keras.layers.Dense(10, activation='softmax')
])

callbacks = [lr_scheduler]

opt = Adam(lr=lr_begin)
model.compile(optimizer=opt,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

Starttime = time.time()
history = model.fit(train_images, 
                    train_labels, 
                    batch_size=128,
                    epochs=Epochs,
                    callbacks = callbacks)
Endtime = time.time()
print("[Info.] Training time is = {0:.2f} min.".format((Endtime-Starttime)/60))
# Out:
# Train on 60000 samples
# Learning rate:  0.001
# Epoch 1/50
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.5262 - accuracy: 0.8230
# Learning rate:  0.001
# Epoch 2/50
# 60000/60000 [==============================] - 3s 43us/sample - loss: 0.4072 - accuracy: 0.8620
# Learning rate:  0.001
# Epoch 3/50
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.3834 - accuracy: 0.8696
# Learning rate:  0.001
# Epoch 4/50
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.3658 - accuracy: 0.8753
# Learning rate:  0.001
# Epoch 5/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.3551 - accuracy: 0.8790
# Learning rate:  0.001
# Epoch 6/50
# 60000/60000 [==============================] - 3s 44us/sample - loss: 0.3436 - accuracy: 0.8827
# Learning rate:  0.001
# Epoch 7/50
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.3381 - accuracy: 0.8854
# Learning rate:  0.001
# ...

# %% [markdown]
# # **모델 평가하기**
#  - 훈련된 이미지 분류기는 이 데이터셋에서 약 97.5%의   정확도를 달성

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 10000/1 - 1s - loss: 0.2694 - accuracy: 0.8932
#
# Test accuracy: 0.8932

# %% [markdown]
# # **모델 저장하기**

# %%
save_dir = "fashionMNIST_final.h5"
model.save(save_dir)

# %% [markdown]
# # **모델 불러오기**

# %%
loadmodel = load_model(save_dir)
test_loss, test_acc = loadmodel.evaluate(test_images, test_labels)
print('테스트 손실 측정결과:', test_loss, ',', '테스트 정확도 측정결과:', test_acc)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...

# %% [markdown]
# # **예측하기**

# %%
# 훈련된 모델로 예측하기
predictions = model.predict(test_images)

# %%
#소프트맥스 출력인 확률값 분포로 예측
predictions[0]
# Out:
# array([4.7891507e-07, 4.4133652e-09, 4.6470823e-06, 1.0185131e-06,
#        3.9962929e-06, 2.0897635e-03, 2.3325974e-05, 2.8638912e-02,
#        1.7417811e-05, 9.6922034e-01], dtype=float32)

# %%
#확률값 기반으로 모델의 신뢰도가 가장 높은 레이블 찾기
np.argmax(predictions[0])
# Out:
# 9

# %%
test_labels[0]
# Out:
# 9

# %% [markdown]
# # **예측한 결과 그래프로 표현하기**

# %%
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], test_labels, test_images)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], test_labels)
plt.tight_layout()
plt.show()
