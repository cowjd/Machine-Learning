# %% [markdown]
# # **colab 서버에서 지원하는 환경 확인하기**

# %%
# colab의 서버에서 지원하고 있는 os는 무엇인지 확인
import platform
platform.platform()
# Out:
# 'Linux-5.4.104+-x86_64-with-Ubuntu-18.04-bionic'

# %% [markdown]
# # **필요 라이브러리 설치하기**

# %%
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.6.0
# Uninstalling tensorflow-2.6.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.6.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.6.0

# %%
# !pip install tensorflow-gpu==2.0.0
# Out:
# ...
#      |████████████████████████████████| 380.8 MB 40 kB/s
# ...
#      |████████████████████████████████| 50 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 39.3 MB/s
# ...
#      |████████████████████████████████| 449 kB 48.0 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=518d956951c897fc2eed340a75db6dcd45dda8bd9ea10af8f02a75896b0487a2
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.6.0
#     Uninstalling tensorflow-estimator-2.6.0:
#       Successfully uninstalled tensorflow-estimator-2.6.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.6.0
#     Uninstalling tensorboard-2.6.0:
#       Successfully uninstalled tensorboard-2.6.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.4.0
# ...

# %%
pip uninstall h5py
# Out:
# Found existing installation: h5py 3.1.0
# Uninstalling h5py-3.1.0:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/h5py-3.1.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/h5py.libs/libaec-9c9e97eb.so.0.0.10
#     /usr/local/lib/python3.7/dist-packages/h5py.libs/libhdf5-00e8fae8.so.200.0.0
#     /usr/local/lib/python3.7/dist-packages/h5py.libs/libhdf5_hl-383c339f.so.200.0.0
#     /usr/local/lib/python3.7/dist-packages/h5py.libs/libsz-e7aa62f5.so.2.0.1
#     /usr/local/lib/python3.7/dist-packages/h5py.libs/libz-eb09ad1d.so.1.2.3
#     /usr/local/lib/python3.7/dist-packages/h5py/*
# Proceed (y/n)? y
#   Successfully uninstalled h5py-3.1.0

# %%
pip install h5py==2.10.0
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 5.1 MB/s
# ...

# %% [markdown]
# # **설치 버전 확인 및 라이브러리 임포트하기**

# %%
import tensorflow as tf
from tensorflow.keras.models import load_model
tf.__version__
# Out:
# '2.0.0'

# %% [markdown]
# # [**MNIST 데이터셋**](http://yann.lecun.com/exdb/mnist/)을 로드하여 준비
#
# ![MNIST sample](https://github.com/khanhlvg/DigitClassifier/raw/master/images/mnist.png)
#
#   - 샘플 값을 정수에서 부동소수로 변환

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # **모델 설계하기**
#   - 층을 차례대로 쌓아 `tf.keras.Sequential` 모델을 만듬.
#
# ![img](https://www.researchgate.net/profile/Haohan-Wang-4/publication/282997080/figure/fig4/AS:305939199610886@1449952997594/A-typical-two-layer-neural-network-Input-layer-does-not-count-as-the-number-of-layers-of.png)

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])

# %% [markdown]
# # **모델 컴파일 수행하기**
#   - 훈련에 사용할 옵티마이저(optimizer)와 손실 함수를 선택

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# # **모델 훈련하기**

# %%
model.fit(x_train, 
          y_train, 
          batch_size=128,
          epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 4s 64us/sample - loss: 0.3598 - accuracy: 0.9007
# Epoch 2/5
# 60000/60000 [==============================] - 2s 33us/sample - loss: 0.1646 - accuracy: 0.9533
# Epoch 3/5
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.1184 - accuracy: 0.9657
# Epoch 4/5
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0909 - accuracy: 0.9738
# Epoch 5/5
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.0745 - accuracy: 0.9782

# %% [markdown]
# # **모델 평가하기**
#  - 훈련된 이미지 분류기는 이 데이터셋에서 약 97.5%의   정확도를 달성

# %%
model.evaluate(x_test,  y_test, verbose=2)
# Out:
# 10000/1 - 1s - loss: 0.0468 - accuracy: 0.9723
# [0.0899539351111278, 0.9723]

# %% [markdown]
# # **모델 저장하기**

# %%
save_dir = "mnist_nn.h5"
model.save(save_dir)

# %% [markdown]
# # **모델 불러오기**

# %%
loadmodel = load_model(save_dir)
test_loss, test_acc = loadmodel.evaluate(x_test, y_test)
print('테스트 손실 측정결과:', test_loss, ',', '테스트 정확도 측정결과:', test_acc)
# Out:
# 10000/1 [=============================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================
# ...
